# %% [markdown]
# ## Calcul du nombre de labels

# %%
import os 
path = 'C:/Users/21694/Desktop/P2M/clean data/labels'
c=0
files = os.listdir(path)
for name in files:
    
    
    
    c+=1
print(c)
# Out:
# 79863

# %% [markdown]
# ## Calcul du nombre d'images

# %%
import os 
path = 'C:/Users/21694/Desktop/P2M/clean data/images'
c=0
files = os.listdir(path)
for name in files:
    
    
    
    c+=1
print(c)
# Out:
# 79221

# %% [markdown]
# ## Calcul du nombre des images non labelisées

# %%
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
list_img=[]
list_label=[]
c=0

for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
    
    
for name in list_img:
    if name not in list_label:
        print(name," image non labelisée")
        c+=1
print(c)
# Out:
# 0

# %% [markdown]
# ## Calcul du nombre des labels sans images

# %%
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
list_img=[]
list_label=[]
c=0

for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
    
    
for name in list_label:
    if name not in list_img:
        print(name,"  label sans image")
        c+=1
print(c)
# Out:
# 00779058-517a4591   label sans image
# 00cea101-293a30b5   label sans image
# 0102614a-75ae85cf   label sans image
# 013742f1-3a043a4e   label sans image
# 019cd27a-b3c5617d   label sans image
# 02d478d1-cfb83eb8   label sans image
# 0391b282-79dba56d   label sans image
# 041dc63f-7fe29e93   label sans image
# 04c9ba23-4f220b11   label sans image
# 04d0ac8f-353c48f3   label sans image
# 052da241-2131247e   label sans image
# 054ce029-9f4216a0   label sans image
# 05d69bf0-7c78fc45   label sans image
# 06031175-b4b8a11e   label sans image
# 0618c64e-e8cfed90   label sans image
# 0675f404-5d0dcb6e   label sans image
# 0676d627-4b8f681b   label sans image
# 07c59519-86d93c33   label sans image
# 08688b9f-1a6e302c   label sans image
# 0889a51d-48ed41be   label sans image
# 088e1da1-4db9234b   label sans image
# 089fcb65-d645e2f9   label sans image
# 08aba9b5-9f0927ea   label sans image
# 08b8e64f-77f35e02   label sans image
# 08c30aed-efd44b47   label sans image
# ...

# %% [markdown]
# # Verifier l'existance de ces images dans la base de donnée originale

# %%
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
path='D:/P2M/data/bdd100k/images/100k/train'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
files = os.listdir(path)
list_img=[]
list_label=[]
list1=[]
c=0

for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
for n3 in files:
    list1.append(n3[:17])    
    
    
for name in list_label:
    if name not in list_img:
        if name  not in list1:
            print(name,"  label sans image")
            c+=1
print(c)
# Out:
# b2156f8e-72e1547c   label sans image
# b3039ada-2ef2a725   label sans image
# b32a9f8b-2b3d9894   label sans image
# b3456910-cf5fb475   label sans image
# b3c21bae-260d0b00   label sans image
# b4715825-e1fbf174   label sans image
# b4b99a3e-21dfc344   label sans image
# b4ef573f-a98f72d3   label sans image
# b5450d0c-ccc3fb86   label sans image
# b5868878-8faf33a2   label sans image
# b5a4b486-35c3edb4   label sans image
# b5b8e198-b661f016   label sans image
# b5d8894a-d99dbb00   label sans image
# b5dd20c5-ed2da652   label sans image
# b61659ca-b9aded69   label sans image
# b6270d75-6999f310   label sans image
# b6658d33-adfea9cf   label sans image
# b6aa41ba-768fdf21   label sans image
# b7064abc-878a912c   label sans image
# b7993af5-b544c0da   label sans image
# b7b07700-7dd6ec37   label sans image
# b7fc87bf-8ac3359e   label sans image
# b804f988-eb510a9a   label sans image
# b86f9b95-e4651840   label sans image
# b8c95e55-7cc3b9b1   label sans image
# ...

# %% [markdown]
# # Verifier l'existance de ces images dans la base de donnée originale

# %%
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
path='D:/P2M/data/bdd100k/images/100k/val'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
files = os.listdir(path)
list_img=[]
list_label=[]
list1=[]
c=0

for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
for n3 in files:
    list1.append(n3[:17])    
    
    
for name in list_label:
    if name not in list_img:
        if name  not in list1:
            print(name,"  label sans image")
            c+=1
print(c)
# Out:
# 00779058-517a4591   label sans image
# 00cea101-293a30b5   label sans image
# 0102614a-75ae85cf   label sans image
# 013742f1-3a043a4e   label sans image
# 019cd27a-b3c5617d   label sans image
# 02d478d1-cfb83eb8   label sans image
# 0391b282-79dba56d   label sans image
# 041dc63f-7fe29e93   label sans image
# 04c9ba23-4f220b11   label sans image
# 04d0ac8f-353c48f3   label sans image
# 052da241-2131247e   label sans image
# 054ce029-9f4216a0   label sans image
# 05d69bf0-7c78fc45   label sans image
# 06031175-b4b8a11e   label sans image
# 0618c64e-e8cfed90   label sans image
# 0675f404-5d0dcb6e   label sans image
# 0676d627-4b8f681b   label sans image
# 07c59519-86d93c33   label sans image
# 08688b9f-1a6e302c   label sans image
# 0889a51d-48ed41be   label sans image
# 088e1da1-4db9234b   label sans image
# 089fcb65-d645e2f9   label sans image
# 08aba9b5-9f0927ea   label sans image
# 08b8e64f-77f35e02   label sans image
# 08c30aed-efd44b47   label sans image
# ...

# %% [markdown]
# # Suppression des labels sans images

# %%
        
        
        
        
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
path='D:/P2M/data/bdd100k/images/100k/val'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
list_img=[]
list_label=[]
l=[]
for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
    
    
for name in list_label:
    if name not in list_img:
        l.append(name)   
        
for i in l :
    print("element supprimé",i)
    c=i+'.txt'
    os.remove(os.path.join(path_l,c))
# Out:
# element supprimé 00779058-517a4591
# element supprimé 00cea101-293a30b5
# element supprimé 0102614a-75ae85cf
# element supprimé 013742f1-3a043a4e
# element supprimé 019cd27a-b3c5617d
# element supprimé 02d478d1-cfb83eb8
# element supprimé 0391b282-79dba56d
# element supprimé 041dc63f-7fe29e93
# element supprimé 04c9ba23-4f220b11
# element supprimé 04d0ac8f-353c48f3
# element supprimé 052da241-2131247e
# element supprimé 054ce029-9f4216a0
# element supprimé 05d69bf0-7c78fc45
# element supprimé 06031175-b4b8a11e
# element supprimé 0618c64e-e8cfed90
# element supprimé 0675f404-5d0dcb6e
# element supprimé 0676d627-4b8f681b
# element supprimé 07c59519-86d93c33
# element supprimé 08688b9f-1a6e302c
# element supprimé 0889a51d-48ed41be
# element supprimé 088e1da1-4db9234b
# element supprimé 089fcb65-d645e2f9
# element supprimé 08aba9b5-9f0927ea
# element supprimé 08b8e64f-77f35e02
# element supprimé 08c30aed-efd44b47
# element supprimé 092183aa-ae5ae55e
# element supprimé 09b2e125-ddb094b4
# ...

# %% [markdown]
# # # verification de la suppression des labels

# %%
import os 
path_i = 'C:/Users/21694/Desktop/P2M/clean data/images'
path_l = 'C:/Users/21694/Desktop/P2M/clean data/labels'
files_i = os.listdir(path_i)
files_l = os.listdir(path_l)
list_img=[]
list_label=[]
c=0

for n1 in files_i:
    list_img.append(n1[:17])
    
    
    
for n2 in files_l:
    list_label.append(n2[:17])
    
    
for name in list_label:
    if name not in list_img:
        print(name,"  label sans image")
        c+=1
print(c)
# Out:
# 0
